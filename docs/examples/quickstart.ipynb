# %% [markdown]
# # Quickstart

# %%
# %pwd
# Out:
# '/lila/home/harrigan/damuta/docs/examples'

# %%
import damuta as da

# %% [markdown]
# Load COSMIC signatures provided in damuta

# %%
da.load_cosmic_V3()
